# %%
import pandas as pd
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression as LR
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.decomposition import NMF
from sklearn.metrics import silhouette_score
from sklearn.metrics import silhouette_samples
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from time import time
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import NullFormatter
import tensorflow as tf
# import torch
# Out:
# D:\Users\admin\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# D:\Users\admin\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# D:\Users\admin\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
data = pd.read_csv('exp1.txt',sep='\t')
# data = data.set_index('Unnamed: 0')
x = data
n_clusters = 4

# %%
x
# Out:
#      original_glcm_InverseVariance_para1  \
# 0                               2.825993
# 1                              -0.480494
# 2                              -0.727110
# 3                               0.089323
# 4                               0.313994
# ..                                   ...
# 402                             0.057641
# 403                            -0.198346
# 404                             0.556593
# 405                            -0.052525
# 406                             0.179978
#
#      original_firstorder_10Percentile_para1  original_shape_MeshVolume_para2  \
# 0                                 -0.967419                         1.937796
# 1                                  1.967777                         0.973277
# 2                                  1.083942                        -0.437778
# 3                                 -0.683356                        -1.045375
# 4                                  2.503886                        -0.634991
# ..                                      ...                              ...
# 402                               -0.133472                        -0.312119
# 403                               -0.282391                        -0.170754
# 404                                2.700459                        -0.741274
# 405                               -0.602567                        -0.366044
# 406                                0.000555                        -0.776927
#
#      original_gldm_LargeDependenceHighGrayLevelEmphasis_para2  \
# 0                                            -1.171537
# 1                                             1.556973
# 2                                            -0.208222
# 3                                            -1.118121
# 4                                            -1.097832
# ..                                                 ...
# 402                                           1.119496
# 403                                           1.619439
# 404                                           2.131727
# 405                                          -0.212453
# 406                                           1.600643
#
#      original_firstorder_Skewness_para2  \
# 0                             -0.299858
# 1                             -1.313059
# 2                              0.292702
# 3                              1.362701
# 4                              0.406250
# ..                                  ...
# 402                           -0.387825
# 403                           -0.125009
# 404                           -2.725526
# 405                            0.168166
# 406                           -1.166518
#
#      original_gldm_LargeDependenceHighGrayLevelEmphasis_para1  \
# 0                                            -1.166825
# 1                                             1.551073
# 2                                            -0.207256
# 3                                            -1.113617
# 4                                            -1.093406
# ..                                                 ...
# 402                                           1.115297
# 403                                           1.613296
# 404                                           2.123591
# 405                                          -0.211471
# 406                                           1.594573
#
#      original_firstorder_RootMeanSquared_para1  original_shape_Flatness_para2  \
# 0                                     1.823600                       0.520856
# 1                                    -1.174176                      -1.094044
# 2                                    -1.053529                      -0.276088
# 3                                     1.239916                       1.204989
# 4                                    -2.037445                      -0.228397
# ..                                         ...                            ...
# 402                                  -0.182644                       0.753925
# 403                                  -0.192977                       0.759172
# 404                                  -1.777009                      -0.167711
# 405                                   0.657552                       0.583963
# 406                                  -0.863517                       0.835690
#
#      original_ngtdm_Contrast_para1  original_firstorder_90Percentile_para1  \
# 0                        -1.043698                               -2.529901
# 1                        -0.603899                                1.255785
# 2                        -0.276520                                0.503132
# 3                        -0.654298                               -1.901157
# 4                        -0.898295                                0.523257
# ..                             ...                                     ...
# 402                       0.804481                                0.422635
# 403                      -0.372793                                0.945869
# 404                      -0.755591                                0.526132
# 405                       0.905907                                0.950756
# 406                       0.059329                                0.365137
#
#      original_glszm_GrayLevelNonUniformityNormalized_para1  \
# 0                                             1.046928
# 1                                            -0.210060
# 2                                            -0.219557
# 3                                            -0.077074
# 4                                            -0.099955
# ..                                                 ...
# 402                                          -0.179730
# 403                                          -0.225820
# 404                                           0.138331
# 405                                          -0.152742
# 406                                          -0.153958
#
#      original_glcm_Id_para1  original_glszm_ZoneVariance_para1  \
# 0                  2.191392                          -0.049723
# 1                 -0.421320                          -0.049917
# 2                 -0.642969                          -0.049937
# 3                 -0.015738                          -0.049923
# 4                  0.307960                          -0.049880
# ..                      ...                                ...
# 402                0.017902                          -0.049887
# 403               -0.198336                          -0.049929
# 404                0.506873                          -0.049892
# 405               -0.095776                          -0.049900
# 406                0.117460                          -0.049899
#
#      original_firstorder_Kurtosis_para1  \
# 0                             -0.257978
# 1                             -0.044878
# 2                             -0.046687
# 3                              0.649007
# 4                             -0.034014
# ..                                  ...
# 402                           -0.409070
# 403                           -0.120064
# 404                            1.057172
# 405                           -0.328575
# 406                           -0.235930
#
#      original_shape_Maximum2DDiameterRow_para1  original_glcm_Idmn_para2  \
# 0                                     1.334224                 -1.779153
# 1                                    -0.073177                  0.567601
# 2                                    -0.628579                  0.564015
# 3                                    -0.874337                  0.064922
# 4                                    -1.080601                  0.233947
# ..                                         ...                       ...
# 402                                  -1.037536                  0.209622
# 403                                   2.883935                  0.808581
# 404                                  -0.153116                  0.708626
# 405                                  -0.874337                  0.330914
# 406                                  -0.990255                  0.332101
#
#      original_glszm_SizeZoneNonUniformityNormalized_para1  \
# 0                                            -2.484012
# 1                                             0.069448
# 2                                             0.794866
# 3                                             0.461965
# 4                                            -0.728153
# ..                                                 ...
# 402                                          -0.400954
# 403                                           0.467990
# 404                                          -0.519547
# 405                                          -0.229138
# 406                                          -0.496662
#
#      original_shape_SurfaceVolumeRatio_para2  \
# 0                                  -0.112961
# 1                                  -0.666765
# 2                                  -0.381890
# 3                                  -0.054545
# 4                                  -0.631441
# ..                                       ...
# 402                                -0.725045
# 403                                 4.775556
# 404                                 0.181904
# 405                                -0.638666
# 406                                -0.608629
#
#      original_firstorder_90Percentile_para2  \
# 0                                 -2.479827
# 1                                  1.254434
# 2                                  0.512006
# 3                                 -1.859624
# 4                                  0.531857
# ..                                      ...
# 402                                0.432601
# 403                                0.948728
# 404                                0.534692
# 405                                0.953549
# 406                                0.375884
#
#      original_shape_SurfaceVolumeRatio_para1
# 0                                  -0.113235
# 1                                  -0.665516
# 2                                  -0.381425
# 3                                  -0.054979
# 4                                  -0.630290
# ..                                       ...
# 402                                -0.723637
# 403                                 4.761850
# 404                                 0.180821
# 405                                -0.637495
# 406                                -0.607540
#
# [407 rows x 20 columns]

# %%
silhouette_score_list = []
harabasz_score_list = []
bouldin_score_list = []
# nmf_silhouette_score_list = []
# nmf_harabasz_score_list = []
# nmf_bouldin_score_list = []
# ae_silhouette_score_list = []
# ae_harabasz_score_list = []
# ae_bouldin_score_list = []
# dae_silhouette_score_list = []
# dae_harabasz_score_list = []
# dae_bouldin_score_list = []
# vae_silhouette_score_list = []
# vae_harabasz_score_list = []
# vae_bouldin_score_list = []

# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances
from sklearn.metrics import silhouette_score
from sklearn.datasets import make_blobs
from sklearn.base import BaseEstimator, ClusterMixin
from sklearn.mixture import GaussianMixture

# %%
cluster_assignments = pd.read_csv('./共识聚类/cluster_4.txt',sep='\t')
cluster_assignments = cluster_assignments['Cluster'].values

# %%
silhouette_score_list.append(silhouette_score(x,cluster_assignments))
harabasz_score_list.append(calinski_harabasz_score(x,cluster_assignments))
bouldin_score_list.append(davies_bouldin_score(x,cluster_assignments))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms

# Sample data (replace with your actual data)
np.random.seed(123)
label = pd.DataFrame(cluster_assignments)

# Perform t-SNE
tsne = TSNE(n_components=2, random_state=123)
a = tsne.fit_transform(x)

# Create DataFrame from t-SNE result
liris = pd.DataFrame(a, index=x.index)

# Boolean indexing
d1 = liris[label[0] == 'C1']
d2 = liris[label[0] == 'C2']
d3 = liris[label[0] == 'C3']
d4 = liris[label[0] == 'C4']

# Plotting
plt.figure(figsize=(12, 8))
type1 = plt.scatter(d1[0], d1[1], s=50, c='#1f77b4', label='A', alpha=0.7, edgecolors='w', linewidth=0.5)
type2 = plt.scatter(d2[0], d2[1], s=50, c='#ff7f0e', label='B', alpha=0.7, edgecolors='w', linewidth=0.5)
type3 = plt.scatter(d3[0], d3[1], s=50, c='#e5192c', label='C', alpha=0.7, edgecolors='w', linewidth=0.5)
type4 = plt.scatter(d4[0], d4[1], s=50, c='#6b7627', label='C', alpha=0.7, edgecolors='w', linewidth=0.5)

# Function to draw ellipses
def plot_ellipse(data, ax, **kwargs):
    cov = np.cov(data, rowvar=False)
    mean = np.mean(data, axis=0)

    # Eigenvalues and eigenvectors
    eigvals, eigvecs = np.linalg.eigh(cov)
    order = eigvals.argsort()[::-1]
    eigvals, eigvecs = eigvals[order], eigvecs[:, order]

    # Angle and width/height of ellipse
    angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
    width, height = 2 * np.sqrt(eigvals)
    
    ellipse = Ellipse(xy=mean, width=width, height=height, angle=angle, **kwargs)
    ax.add_patch(ellipse)

ax = plt.gca()
plot_ellipse(d1, ax, edgecolor='#1f77b4', fc='None', lw=2)
plot_ellipse(d2, ax, edgecolor='#ff7f0e', fc='None', lw=2)
plot_ellipse(d3, ax, edgecolor='#e5192c', fc='None', lw=2)
plot_ellipse(d4, ax, edgecolor='#6b7627', fc='None', lw=2)

plt.legend(fontsize=22)
plt.xlabel('t-SNE Component 1', fontsize=20)
plt.ylabel('t-SNE Component 2', fontsize=20)
# plt.title('t-SNE Plot of Cluster Assignments', fontsize=16)
plt.grid(True, linestyle='--', alpha=0.6)
# Hide x and y axis ticks
plt.tick_params(
    axis='both',       # changes apply to both x and y-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    left=False,        # ticks along the left edge are off
    right=False,       # ticks along the right edge are off
    labelleft=False,   # labels along the left edge are off
    labelbottom=False  # labels along the bottom edge are off
)
plt.savefig('四类标签_CON.jpg', bbox_inches='tight', pad_inches=0.1, dpi=600)
plt.show()

# %%
cluster_assignments = pd.read_csv('./NMF/cluster_4.txt',sep='\t')
cluster_assignments = cluster_assignments['Cluster'].values

# %%
silhouette_score_list.append(silhouette_score(x,cluster_assignments))
harabasz_score_list.append(calinski_harabasz_score(x,cluster_assignments))
bouldin_score_list.append(davies_bouldin_score(x,cluster_assignments))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms

# Sample data (replace with your actual data)
np.random.seed(123)
# x = pd.DataFrame(np.random.rand(100, 4), columns=['A', 'B', 'C', 'D'])
# cluster_assignments = np.random.choice(['C1', 'C2'], size=100)
label = pd.DataFrame(cluster_assignments)

# Perform t-SNE
tsne = TSNE(n_components=2, random_state=123)
a = tsne.fit_transform(x)

# Create DataFrame from t-SNE result
liris = pd.DataFrame(a, index=x.index)

# Boolean indexing
d1 = liris[label[0] == 'C1']
d2 = liris[label[0] == 'C2']
d3 = liris[label[0] == 'C3']
d4 = liris[label[0] == 'C4']

# Plotting
plt.figure(figsize=(12, 8))
type1 = plt.scatter(d1[0], d1[1], s=50, c='#1f77b4', label='A', alpha=0.7, edgecolors='w', linewidth=0.5)
type2 = plt.scatter(d2[0], d2[1], s=50, c='#ff7f0e', label='B', alpha=0.7, edgecolors='w', linewidth=0.5)
type3 = plt.scatter(d3[0], d3[1], s=50, c='#e5192c', label='C', alpha=0.7, edgecolors='w', linewidth=0.5)
type4 = plt.scatter(d4[0], d4[1], s=50, c='#6b7627', label='D', alpha=0.7, edgecolors='w', linewidth=0.5)

# Function to draw ellipses
def plot_ellipse(data, ax, **kwargs):
    cov = np.cov(data, rowvar=False)
    mean = np.mean(data, axis=0)

    # Eigenvalues and eigenvectors
    eigvals, eigvecs = np.linalg.eigh(cov)
    order = eigvals.argsort()[::-1]
    eigvals, eigvecs = eigvals[order], eigvecs[:, order]

    # Angle and width/height of ellipse
    angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
    width, height = 2 * np.sqrt(eigvals)
    
    ellipse = Ellipse(xy=mean, width=width, height=height, angle=angle, **kwargs)
    ax.add_patch(ellipse)

ax = plt.gca()
plot_ellipse(d1, ax, edgecolor='#1f77b4', fc='None', lw=2)
# plot_ellipse(d2, ax, edgecolor='#ff7f0e', fc='None', lw=2)
plot_ellipse(d3, ax, edgecolor='#e5192c', fc='None', lw=2)
plot_ellipse(d4, ax, edgecolor='#6b7627', fc='None', lw=2)

plt.legend(fontsize=22)
plt.xlabel('t-SNE Component 1', fontsize=20)
plt.ylabel('t-SNE Component 2', fontsize=20)
# plt.title('t-SNE Plot of Cluster Assignments', fontsize=16)
plt.grid(True, linestyle='--', alpha=0.6)
# Hide x and y axis ticks
plt.tick_params(
    axis='both',       # changes apply to both x and y-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    left=False,        # ticks along the left edge are off
    right=False,       # ticks along the right edge are off
    labelleft=False,   # labels along the left edge are off
    labelbottom=False  # labels along the bottom edge are off
)
plt.savefig('四类标签_NMF.jpg', bbox_inches='tight', pad_inches=0.1, dpi=600)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms

# Assuming x is your data and cluster_assignments are your initial labels.
# Replace this with your actual data loading process.
np.random.seed(123)
data = pd.read_csv('exp1.txt', sep='\t')
x = data

# Performing k-means clustering
model = KMeans(n_clusters=3, random_state=123)
cluster_assignments = model.fit_predict(x)
label = pd.DataFrame(cluster_assignments, columns=['Cluster'])

# Perform t-SNE for dimensionality reduction
tsne = TSNE(n_components=2, random_state=123)
a = tsne.fit_transform(x)

# Create DataFrame from t-SNE result
liris = pd.DataFrame(a, index=x.index)

# Boolean indexing to separate clusters
d1 = liris[label['Cluster'] == 0]
d2 = liris[label['Cluster'] == 1]

# Plotting
plt.figure(figsize=(12, 8))
type1 = plt.scatter(d1[0], d1[1], s=50, c='#1f77b4', label='A', alpha=0.7, edgecolors='w', linewidth=0.5)
type2 = plt.scatter(d2[0], d2[1], s=50, c='#ff7f0e', label='B', alpha=0.7, edgecolors='w', linewidth=0.5)
type3 = plt.scatter(d3[0], d3[1], s=50, c='#e5192c', label='C', alpha=0.7, edgecolors='w', linewidth=0.5)
type4 = plt.scatter(d4[0], d4[1], s=50, c='#6b7627', label='D', alpha=0.7, edgecolors='w', linewidth=0.5)

# Function to draw ellipses around the data points
def plot_ellipse(data, ax, **kwargs):
    cov = np.cov(data, rowvar=False)
    mean = np.mean(data, axis=0)
    eigvals, eigvecs = np.linalg.eigh(cov)
    order = eigvals.argsort()[::-1]
    eigvals, eigvecs = eigvals[order], eigvecs[:, order]
    angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
    width, height = 2 * np.sqrt(eigvals)
    ellipse = Ellipse(xy=mean, width=width, height=height, angle=angle, **kwargs)
    ax.add_patch(ellipse)

# Adding ellipses to the plot
ax = plt.gca()
plot_ellipse(d1, ax, edgecolor='#1f77b4', fc='None', lw=2)
plot_ellipse(d2, ax, edgecolor='#ff7f0e', fc='None', lw=2)
plot_ellipse(d3, ax, edgecolor='#e5192c', fc='None', lw=2)
plot_ellipse(d4, ax, edgecolor='#6b7627', fc='None', lw=2)

plt.legend(fontsize=22)
plt.xlabel('t-SNE Component 1', fontsize=20)
plt.ylabel('t-SNE Component 2', fontsize=20)
# plt.title('t-SNE Plot of K-means Clusters', fontsize=16)
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tick_params(
    axis='both',       # changes apply to both x and y-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    left=False,        # ticks along the left edge are off
    right=False,       # ticks along the right edge are off
    labelleft=False,   # labels along the left edge are off
    labelbottom=False  # labels along the bottom edge are off
)
plt.savefig('四类标签_Kmeans.jpg', bbox_inches='tight', pad_inches=0.1, dpi=600)
plt.show()
# Out:
# D:\Users\admin\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
silhouette_score_list.append(silhouette_score(x,cluster_assignments))
harabasz_score_list.append(calinski_harabasz_score(x,cluster_assignments))
bouldin_score_list.append(davies_bouldin_score(x,cluster_assignments))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from matplotlib.patches import Ellipse

# Assuming x is your data and cluster_assignments are your initial labels.
# Replace this with your actual data loading process.
np.random.seed(123)
H = pd.read_csv('U1_86.csv', header=None)
x = H

# Performing k-means clustering
model = KMeans(n_clusters=4, random_state=123)
cluster_assignments = model.fit_predict(x)
label = pd.DataFrame(cluster_assignments, columns=['Cluster'])

# Perform t-SNE for dimensionality reduction
tsne = TSNE(n_components=2, random_state=123)
a = tsne.fit_transform(x)

# Create DataFrame from t-SNE result
liris = pd.DataFrame(a, index=x.index)

# Boolean indexing to separate clusters
d1 = liris[label['Cluster'] == 0]
d2 = liris[label['Cluster'] == 1]
d3 = liris[label['Cluster'] == 2]
d4 = liris[label['Cluster'] == 3]

# Plotting
plt.figure(figsize=(12, 8))
type1 = plt.scatter(d1[0], d1[1], s=50, c='#1f77b4', label='A', alpha=0.7, edgecolors='w', linewidth=0.5)
type2 = plt.scatter(d2[0], d2[1], s=50, c='#ff7f0e', label='B', alpha=0.7, edgecolors='w', linewidth=0.5)
type3 = plt.scatter(d3[0], d3[1], s=50, c='#e5192c', label='C', alpha=0.7, edgecolors='w', linewidth=0.5)
type4 = plt.scatter(d4[0], d4[1], s=50, c='#6b7627', label='D', alpha=0.7, edgecolors='w', linewidth=0.5)

# Function to draw ellipses around the data points
def plot_ellipse(data, ax, **kwargs):
    cov = np.cov(data, rowvar=False)
    mean = np.mean(data, axis=0)
    eigvals, eigvecs = np.linalg.eigh(cov)
    order = eigvals.argsort()[::-1]
    eigvals, eigvecs = eigvals[order], eigvecs[:, order]
    angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))
    width, height = 2 * np.sqrt(eigvals)
    ellipse = Ellipse(xy=mean, width=width, height=height, angle=angle, **kwargs)
    ax.add_patch(ellipse)

# Adding ellipses to the plot
ax = plt.gca()
plot_ellipse(d1, ax, edgecolor='#1f77b4', fc='None', lw=2)
plot_ellipse(d2, ax, edgecolor='#ff7f0e', fc='None', lw=2)
plot_ellipse(d3, ax, edgecolor='#e5192c', fc='None', lw=2)
plot_ellipse(d4, ax, edgecolor='#6b7627', fc='None', lw=2)

plt.legend(fontsize=22)
plt.xlabel('t-SNE Component 1', fontsize=20)
plt.ylabel('t-SNE Component 2', fontsize=20)
# plt.title('t-SNE Plot of Cluster Assignments (KMeans)', fontsize=16)
plt.grid(True, linestyle='--', alpha=0.6)
plt.savefig('四类标签_DNMF.jpg', bbox_inches='tight', pad_inches=0.1, dpi=600)
plt.show()
# Out:
# D:\Users\admin\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
silhouette_score_list.append(silhouette_score(x,cluster_assignments))
harabasz_score_list.append(calinski_harabasz_score(x,cluster_assignments))
bouldin_score_list.append(davies_bouldin_score(x,cluster_assignments))

# %%
bouldin_score_list
# Out:
# [1.6380945056075795, 4.039681559973944, 1.7375441964817322, 0.7549417660858306]

# %%
silhouette_score_list
# Out:
# [0.18948883102253994,
#  0.012261276365423299,
#  0.1611250868490194,
#  0.4434224141081193]

# %%
harabasz_score_list
# Out:
# [75.02447134280014, 11.074640097595815, 80.86939746050894, 503.3952111646952]
